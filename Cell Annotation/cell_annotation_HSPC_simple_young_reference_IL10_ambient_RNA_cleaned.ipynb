# %%
library(SeuratDisk)
library(Seurat)
library(SingleCellExperiment)
library(SingleR)


Convert("/store/Projects/pantovski/IL10/Old_naive/write/Ambient_RNA_Cleaned/Old_naive_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.h5ad", dest = "h5seurat", overwrite = TRUE)
Convert("/store/Projects/pantovski/IL10/Old_transplanted/write/Ambient_RNA_Cleaned/Old_transplanted_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.h5ad", dest = "h5seurat", overwrite = TRUE)
Convert("/store/Projects/pantovski/IL10/Young_naive/write/Ambient_RNA_Cleaned/Young_naive_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.h5ad", dest = "h5seurat", overwrite = TRUE)
Convert("/store/Projects/pantovski/IL10/Young_transplanted_separate/write/Ambient_RNA_Cleaned/Young_transplanted_separate_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR_HSC_only.h5ad", dest = "h5seurat", overwrite = TRUE)
Convert("/store/Projects/pantovski/IL10/Combined/write/Ambient_RNA_Cleaned/Old_2_UMI_5_percent_Combat_raw_SingleR_lognorm_raw_SingleR.h5ad", dest = "h5seurat", overwrite = TRUE)

Old <- LoadH5Seurat("/store/Projects/pantovski/IL10/Combined/write/Ambient_RNA_Cleaned/Old_2_UMI_5_percent_Combat_raw_SingleR_lognorm_raw_SingleR.h5seurat")
Old.sce <- as.SingleCellExperiment(Old)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

Old_pred <- SingleR(test=Old.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(Old_pred$labels)
write.csv(Old_pred, file = "/store/Projects/pantovski/IL10/Combined/write/Ambient_RNA_Cleaned/Old_2_UMI_5_percent_Combat_raw_SingleR_cell_types.csv")

Old_transplanted <- LoadH5Seurat("/store/Projects/pantovski/IL10/Old_transplanted/write/Ambient_RNA_Cleaned/Old_transplanted_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.h5seurat")
Old_transplanted.sce <- as.SingleCellExperiment(Old_transplanted)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

Old_transplanted_pred <- SingleR(test=Old_transplanted.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(Old_transplanted_pred$labels)
write.csv(Old_transplanted_pred, file = "/store/Projects/pantovski/IL10/Old_transplanted/write/Ambient_RNA_Cleaned/Old_transplanted_Ambient_RNA_cleaned_cell_types_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.csv")

Old_naive <- LoadH5Seurat("/store/Projects/pantovski/IL10/Old_naive/write/Ambient_RNA_Cleaned/Old_naive_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.h5seurat")
Old_naive.sce <- as.SingleCellExperiment(Old_naive)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

Old_naive_pred <- SingleR(test=Old_naive.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(Old_naive_pred$labels)
write.csv(Old_naive_pred, file = "/store/Projects/pantovski/IL10/Old_naive/write/Ambient_RNA_Cleaned/Old_naive_Ambient_RNA_cleaned_cell_types_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.csv")

Young_naive <- LoadH5Seurat("/store/Projects/pantovski/IL10/Young_naive/write/Ambient_RNA_Cleaned/Young_naive_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.h5seurat")
Young_naive.sce <- as.SingleCellExperiment(Young_naive)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

Young_naive_pred <- SingleR(test=Young_naive.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(Young_naive_pred$labels)
write.csv(Young_naive_pred, file = "/store/Projects/pantovski/IL10/Young_naive/write/Ambient_RNA_Cleaned/Young_naive_Ambient_RNA_cleaned_cell_types_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR.csv")

Young_transplanted <- LoadH5Seurat("/store/Projects/pantovski/IL10/Young_transplanted_separate/write/Ambient_RNA_Cleaned/Young_transplanted_separate_Ambient_RNA_cleaned_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR_HSC_only.h5seurat")
Young_transplanted.sce <- as.SingleCellExperiment(Young_transplanted)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

Young_transplanted_pred <- SingleR(test=Young_transplanted.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(Young_transplanted_pred$labels)
write.csv(Young_transplanted_pred, file = "/store/Projects/pantovski/IL10/Young_transplanted_separate/write/Ambient_RNA_Cleaned/Young_transplanted_separate_Ambient_RNA_cleaned_cell_types_lognorm_join_inner_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress_combat_raw_SingleR_HSC_only.csv")
# Out:
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
# Attaching SeuratObject
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
# ...
